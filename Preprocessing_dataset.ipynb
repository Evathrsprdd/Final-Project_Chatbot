# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df= pd.read_csv('/content/drive/MyDrive/finpro.csv')
df
# Out:
#                                    Title  \
# 0                       Ayam Woku Manado
# 1               Ayam goreng tulang lunak
# 2                       Ayam cabai kawin
# 3                            Ayam Geprek
# 4                            Minyak Ayam
# ...                                  ...
# 15326                 Udang saus mentega
# 15327                 Jipang tumis udang
# 15328                  Tumis Udang Tempe
# 15329  Tumis kacang panjang terong udang
# 15330                  Siomay Udang Ayam
#
#                                              Ingredients  \
# 0      1 Ekor Ayam Kampung (potong 12)--2 Buah Jeruk ...
# 1      1 kg ayam (dipotong sesuai selera jangan kecil...
# 2      1/4 kg ayam--3 buah cabai hijau besar--7 buah ...
# 3      250 gr daging ayam (saya pakai fillet)--Secuku...
# 4      400 gr kulit ayam & lemaknya--8 siung bawang p...
# ...                                                  ...
# 15326  1 kg udang segar--1 buah bawang bombay kecil--...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15331 entries, 0 to 15330
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             15331 non-null  object
#  1   Ingredients       15331 non-null  object
#  2   Steps             15331 non-null  object
#  3   Loves             15331 non-null  int64
#  4   URL               15331 non-null  object
#  5   IngredientLength  15331 non-null  int64
#  6   StepLength        15331 non-null  int64
#  7   SourceFile        15331 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 958.3+ KB

# %%
df.isna().sum()
# Out:
# Title               0
# Ingredients         0
# Steps               0
# Loves               0
# URL                 0
# IngredientLength    0
# StepLength          0
# SourceFile          0
# dtype: int64

# %%
print("Jumlah duplikasi: ", df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
df['Loves'].describe()
# Out:
# count    15331.000000
# mean         9.908290
# std         12.009072
# min          0.000000
# 25%          3.000000
# 50%          6.000000
# 75%         11.000000
# max        111.000000
# Name: Loves, dtype: float64

# %%
low = df[df['Loves'] <= 3].sample(n=167, random_state=42)
medium = df[(df['Loves'] > 3) & (df['Loves'] <= 11)].sample(n=167, random_state=42)
high = df[df['Loves'] > 11].sample(n=166, random_state=42)

sample_df = pd.concat([low, medium, high]).reset_index(drop=True)

print(sample_df.shape)


# import pandas as pd

# mean_love = df['Loves'].mean()

# # Tentukan rentang sekitar rata-rata (misalnya ±20%)
# lower = mean_love * 0.8
# upper = mean_love * 1.2

# # Filter data dalam rentang ini
# near_mean = df[(df['Loves'] >= lower) & (df['Loves'] <= upper)]

# # Ambil 5 baris acak
# sample_df = near_mean.sample(n=5, random_state=42)

# sample_df[['Title', 'Loves']]
# Out:
# (500, 8)

# %%
sample_df.head()
# Out:
#                                      Title  \
# 13511  Nasi Bakar isi Balado udang kentang
# 2501                          Pecak gurame
# 8635          Pepes Tahu Ikan Teri Special
# 5812                   Lodehan Daging sapi
# 10885         Telur rebus + udang cabe ijo
#
#                                              Ingredients  \
# 13511  1/4 kg beras putih--1/2 bks santan (aku pakai ...
# 2501   1 ekor ikan gurame--jeruk nipis--bumbu ikan(ha...
# 8635   5 buah tahu kuning--3 Siung bawah merah--3 siu...
# 5812   200 gr Daging sapi, potong kotak--2 wortel,iri...
# 10885  2 butir telur ayam--Udang sedikit yg tersisa d...
#
#                                                    Steps  Loves  \
# 13511  Siapkan rice cooker. Cuci beras, masukkan ke d...     10
# 2501   Bersihkan ikan gurame,lumurin dengan perasan j...      9
# 8635   Iris bawang merah, bawang putih, cabai merah, ...      8
# 5812   Persiapan bahan--Haluskan bumbu--Rebus daging ...      8
# ...

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             500 non-null    object
#  1   Ingredients       500 non-null    object
#  2   Steps             500 non-null    object
#  3   Loves             500 non-null    int64
#  4   URL               500 non-null    object
#  5   IngredientLength  500 non-null    int64
#  6   StepLength        500 non-null    int64
#  7   SourceFile        500 non-null    object
# dtypes: int64(3), object(5)
# memory usage: 31.4+ KB

# %%
selected_df = sample_df[['Title', 'Ingredients', 'Steps', 'URL']]
selected_df
# Out:
#                                    Title  \
# 0                       Tongseng Kambing
# 1             Nasi kebuli ayam megic com
# 2                      Tumis Udang Pedas
# 3                     Tempe kering manis
# 4              Bothok tahu tempe jerohan
# ..                                   ...
# 495  Udang goreng tepung saos asam manis
# 496                           Semur Tahu
# 497                 Tahu bacem sederhana
# 498                          Dimsum Ayam
# 499                   Mesere daging sapi
#
#                                            Ingredients  \
# 0    Bahan:--250 gr daging kambing--2 lembar daun s...
# 1    3 cup beras biasa--1/2 dada ayam, potong dadu ...
# 2    1/4 kg udang bersihkan kepala dan ekornya--3 b...
# 3    1 buah tempe (iris kotak2)--iris Bumbu--3 siun...
# 4    250 g jerohan--1 papan tempe--1 papan tahu--10...
# ..                                                 ...
# 495  250 gr udang kecil--Tepung bumbu serbaguna me ...
# ...

# %%
selected_df.to_csv('dataset.csv', index=None)
